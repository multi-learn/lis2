# %%
from utils import *

# %%
reformat_threed("dataset/COHRS_16p50_0p00_3D.fits", "dataset/NH2_16p50_0p00_spine.fits", name_newfile="dataset/testmin.fits")
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 56466.459745 from DATE-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477034 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.822799 from OBSGEO-[XYZ].
# Set OBSGEO-H to     4117.025 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
data3d_reformated = open_fits_data("dataset/testmin.fits")
# Out:
# Filename: dataset/testmin.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    1199   (157, 313, 788)   float64
# None
# ...

# %%
data3d_reformated.shape
# Out:
# (788, 313, 157)

# %%
data3d_reformated[300,:,:]
# Out:
# array([[-0.92023262, -0.92023262, -0.92023262, ..., -0.92023262,
#         -0.92023262, -0.92023262],
#        [-0.92023262,  0.03046372, -0.0131892 , ..., -0.01831518,
#         -0.92023262, -0.92023262],
#        [-0.92023262, -0.12676642, -0.19043951, ..., -0.19207141,
#         -0.92023262, -0.92023262],
#        ...,
#        [-0.92023262, -0.26995295, -0.08885007, ...,  0.0317807 ,
#         -0.92023262, -0.92023262],
#        [-0.92023262, -0.92023262, -0.92023262, ..., -0.92023262,
#         -0.92023262, -0.92023262],
#        [-0.92023262, -0.92023262, -0.92023262, ..., -0.92023262,
#         -0.92023262, -0.92023262]], dtype='>f8')

# %%
show_fits_data(data3d_reformated[560,:,:])
